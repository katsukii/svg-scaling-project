# %% [markdown]
# # Large Model Training (33.6M params)
#
# SVG Scaling Laws Project — Part 2

# %% [markdown]
# ## 1. Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/SVGScalingLawProject/svg-scaling-project.zip -d /content/

# %%
# !pip install -q pyyaml

# %% [markdown]
# ## 2. Verify

# %%
import torch
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

# !ls /content/svg-scaling-project/data/tokenized/
# Out:
# CUDA: True
# GPU: NVIDIA A100-SXM4-40GB
# Memory: 42.4 GB
# test.bin  tokenize_stats.json  train.bin  val.bin

# %% [markdown]
# ## 3. Train Large

# %%
# %cd /content/svg-scaling-project
# !python src/train.py \
    --config configs/large.yaml \
    --learning-rate 3e-3 \
    --output-dir results/runs/scaling_study/large \
    --device cuda
# Out:
# /content/svg-scaling-project
# Using device: cuda
# Loading tokenized data...
# Train tokens: 110,325,825, Val tokens: 11,195,284
# Model parameters: 33,565,184 (33.57M)
# Max steps: 6733, Warmup steps: 201
# Tokens per step: 16,384
# Output dir: results/runs/scaling_study/large
# step      0/6733 | loss 8.4145 | lr 1.49e-05 | 1.1s | 16,384 tokens
# step     50/6733 | loss 3.4191 | lr 7.61e-04 | 12.7s | 835,584 tokens
# step    100/6733 | loss 2.9148 | lr 1.51e-03 | 24.4s | 1,654,784 tokens
# step    150/6733 | loss 3.5947 | lr 2.25e-03 | 36.2s | 2,473,984 tokens
# step    200/6733 | loss 3.3925 | lr 3.00e-03 | 48.0s | 3,293,184 tokens
#   → eval train_loss=3.0274, val_loss=4.5311, val_ppl=92.86
#   → New best val_loss=4.5311, saved checkpoint
# step    250/6733 | loss 2.9772 | lr 3.00e-03 | 67.6s | 4,112,384 tokens
# step    300/6733 | loss 2.4611 | lr 3.00e-03 | 79.4s | 4,931,584 tokens
# step    350/6733 | loss 2.2300 | lr 3.00e-03 | 91.2s | 5,750,784 tokens
# ...

# %% [markdown]
# ## 4. Save Results to Drive

# %%
# !mkdir -p /content/drive/MyDrive/SVGScalingLawProject/large_results
# !cp results/runs/scaling_study/large/summary.json /content/drive/MyDrive/large_results/
# !cp results/runs/scaling_study/large/training_log.json /content/drive/MyDrive/large_results/
# !cp results/runs/scaling_study/large/best_model.pt /content/drive/MyDrive/large_results/

# !cat results/runs/scaling_study/large/summary.json
# Out:
# cp: cannot create regular file '/content/drive/MyDrive/large_results/': Not a directory
# cp: cannot create regular file '/content/drive/MyDrive/large_results/': Not a directory
# cp: cannot create regular file '/content/drive/MyDrive/large_results/': Not a directory
# {
#   "config": {
#     "model": {
#       "vocab_size": 4096,
#       "block_size": 1024,
#       "n_layer": 10,
#       "n_head": 8,
#       "n_embd": 512,
#       "d_ff": 2048,
#       "dropout": 0.0,
#       "bias": false
#     },
#     "training": {
#       "batch_size": 16,
#       "learning_rate": 0.003,
#       "weight_decay": 0.1,
#       "betas": [
#         0.9,
#         0.95
#       ],
#       "grad_clip": 1.0,
#       "warmup_frac": 0.03,
#       "min_lr_frac": 0.1,
#       "max_steps": null,
#       "eval_interval": 200,
#       "eval_steps": 50,
#       "log_interval": 50,
#       "checkpoint_interval": 1000
#     },
#     "data": {
# ...
